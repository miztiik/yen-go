# %% [markdown]
# # 05 — Quantize to GGUF Q4
#
# **Runs on: GPU machine (or CPU with enough RAM)**
#
# Convert Tier 2 (Qwen3-0.6B) checkpoint to GGUF Q4_K_M format
# for browser deployment via wllama/llama.cpp WASM.
#
# ## Output
# - `data/models/yen-sei-tier2.gguf` (~350-400 MB)

# %%
# TODO: Implement after Tier 2 training
print('Not yet implemented — run 04_distill_tier2_qwen3.ipynb first')
