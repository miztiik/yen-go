# %% [markdown]
# # 03 — Generate Synthetic Data via Tier 1
#
# **Runs on: GPU machine**
#
# Use the fine-tuned Gemma 4 E2B (Tier 1) to mass-produce teaching comments
# for puzzles that have solution trees but no human teaching comments.
# This generates 20K+ synthetic training examples at zero API cost.
#
# ## Input
# - Puzzles from kisvadim (19K), gotools (23K), tsumegodragon (12K)
# - Tier 1 model checkpoint from notebook 02
#
# ## Output
# - `data/synthetic.jsonl` — synthetic training examples

# %%
# TODO: Implement after Tier 1 training is complete
print('Not yet implemented — run 02_train_tier1_gemma4.ipynb first')
