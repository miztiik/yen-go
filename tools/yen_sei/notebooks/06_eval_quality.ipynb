# %% [markdown]
# # 06 — Evaluate Model Quality
#
# **Runs on: GPU machine**
#
# Score both Tier 1 (Gemma 4 E2B) and Tier 2 (Qwen3-0.6B) against
# the held-out test set. Compare quality gap between tiers.
#
# ## Metrics
# - JSON parse success rate (must output valid TeachingOutput)
# - BLEU/ROUGE against reference comments
# - VP constraint compliance (15-word cap, verb-forward)
# - Output length distribution
# - Tier 1 vs Tier 2 comparison

# %%
# TODO: Implement after both tiers are trained
print('Not yet implemented — run training notebooks first')
