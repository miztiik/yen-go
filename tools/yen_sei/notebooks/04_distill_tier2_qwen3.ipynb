# %% [markdown]
# # 04 — Distill Tier 2: Qwen3-0.6B
#
# **Runs on: GPU machine**
#
# LoRA fine-tune Qwen3-0.6B on natural + synthetic data (from Tier 1).
# This smaller model runs in the browser via WASM for on-demand hints.
#
# ## Input
# - `data/sft.jsonl` (natural teaching data)
# - `data/synthetic.jsonl` (Tier 1 generated)
#
# ## Output
# - Merged checkpoint in `data/models/yen-sei-tier2/`

# %%
# TODO: Implement after synthetic data generation
print('Not yet implemented — run 03_generate_synthetic.ipynb first')
